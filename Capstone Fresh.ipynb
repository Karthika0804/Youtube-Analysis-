# %%
pip install google.api.python.client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
pip install Ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.errors import HttpError
import json
import re

# %%
api_key = "AIzaSyDQn72EMeyGBozU6vC4tFjncvRGvUQLGzo"

# %%
#api_key = 'AIzaSyDH_Y9CrF1YKw0k-FfyDbns40ne05huRhU'
api_service_name = "youtube"
api_version = "v3"
youtube =build(api_service_name, api_version, developerKey= api_key)

# %% [markdown]
# # Function for one channel info

# %%
channel_id='UCnz-ZXXER4jOvuED5trXfEA'# techTFQ
#channel_id='UUiv4AccPaqsv_Jdr2dmu92A' #mycycling spot

# %%
def get_channel_stats(youtube,channel_id):
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=channel_id)
    response = request.execute() 
    data = dict(Channel_name = response['items'][0]['snippet']['title'],
                    Subscribers = response['items'][0]['statistics']['subscriberCount'],
                    Views = response['items'][0]['statistics']['viewCount'],
                    Total_videos = response['items'][0]['statistics']['videoCount']
                   
               )
    return data

# %%
channel_details = get_channel_stats(youtube,channel_id)
channel_details
# Out:
# {'Channel_name': 'techTFQ',
#  'Subscribers': '218000',
#  'Views': '10913123',
#  'Total_videos': '89'}

# %% [markdown]
# # Function to get multiple channel details

# %%
#channel_ids = ["UCxQuP9Qv49QnWeUY7Tp1HOw","RuuXzTIr0OoDqI4S0RU6n4FqKEM"]
channel_ids=['UCnz-ZXXER4jOvuED5trXfEA',"UC_x5XG1OV2P6uZZ5FSM9Ttw","UCsBX7Ui2qnM27GXVaZ1F3kQ","UCxQuP9Qv49QnWeUY7Tp1HOw","UCBnZ16ahKA2DZ_T5W0FPUXg",
              "UCk3JZr7eS3pg5AGEvBdEvFg","UChL9x-Q75LCuYHIFRDT_T1A","UCvrhwpnp2DHYQ1CbXby9ypQ","UCmxUSaxdeXP5eTfZUSIRSxg",
             "UCduIoIMfD8tT3KoU0-zBRgQ","UCgcUFVynuKwaIZLJkjhzOVg","UCBbgQlTV9z0qwjeofwtkhWg","UCiv4AccPaqsv_Jdr2dmu92A"]

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_stats=get_channel_stats(youtube,channel_ids)
channel_stats
# Out:
# [{'Channel_name': 'GUVI',
#   'Subscribers': '79100',
#   'Views': '2680727',
#   'Total_videos': '1041',
#   'playlist_id': 'UUduIoIMfD8tT3KoU0-zBRgQ'},
#  {'Channel_name': 'MaddyEats',
#   'Subscribers': '4160000',
#   'Views': '1205413124',
#   'Total_videos': '410',
#   'playlist_id': 'UUgcUFVynuKwaIZLJkjhzOVg'},
#  {'Channel_name': 'News7Tamil Bakthi',
#   'Subscribers': '150000',
#   'Views': '40496397',
#   'Total_videos': '5632',
#   'playlist_id': 'UUBbgQlTV9z0qwjeofwtkhWg'},
#  {'Channel_name': 'techTFQ',
#   'Subscribers': '218000',
#   'Views': '10913123',
#   'Total_videos': '89',
#   'playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_name': 'D Sathish',
#   'Subscribers': '0',
#   'Views': '0',
#   'Total_videos': '0',
#   'playlist_id': 'UUxQuP9Qv49QnWeUY7Tp1HOw'},
#  {'Channel_name': 'ChuChu TV Nursery Rhymes & Kids Songs',
#   'Subscribers': '66100000',
#   'Views': '45958410338',
#   'Total_videos': '633',
#   'playlist_id': 'UUBnZ16ahKA2DZ_T5W0FPUXg'},
# ...

# %% [markdown]
# # Function to get video_ids

# %%
playlist_id='UUnz-ZXXER4jOvuED5trXfEA'

# %%
def get_video_ids(youtube,channel_id):
    video_ids = []
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
            next_page_token = response.get('nextPageToken')
        
    return (video_ids)

# %%
video_ids= get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['0QcEqFrhb_Y',
#  'smztq8sRAhk',
#  '7skZzocEU6c',
#  'LZGaRcDxj8I',
#  'rBPQ5fg_kiY',
#  'hvwltYazuQo',
#  'a-hFbr-4VQQ',
#  'pMNcPLc9Z7c',
#  'zZKb8FQRShs',
#  'jS5_hjFgfzA',
#  '6UAU79FNBjQ',
#  'ZwFfiadQB3k',
#  'Det4ZjBSe3M',
#  'xUsY2jWQa1w',
#  'ueOUSjdAZY8',
#  '90iK6gGvG_g',
#  'hsaPfEvForM',
#  'jb8XlF2dkoY',
#  'WhkNQ3g0U64',
#  '_suB8xV9aPc',
#  'dWHSt0BVlv0',
#  'xJVWL7eMir0',
#  'h48xzQR3wNQ',
#  'S5gX-LLAZIM',
#  'LNlzx-YX8rI',
#  'WzkBZ0byoYE',
#  'weCZ1WynbMI',
#  '3dOxGYkpVbE',
#  '9dLXZrw6nac',
#  'i3xK7Nc414Q',
#  'H7YMumanHBA',
#  '4p-G7fGhqRk',
#  'yLR1w4tZ36I',
#  '-DiOp9vAEuM',
#  'O1o9m9T1c3k',
#  '7hZYh9qXxe4',
#  'aE623ff7zkM',
#  'eXJGjbDo5KY',
#  'O52sweYbCyI',
#  'cLSxasHg9WY',
#  'l6XhSFAyvO0',
#  'nJIEIzF7tDw',
#  'RehbnzKHS28',
#  '0OQJDd3QqQM',
#  'V6KPbGLYL4A',
#  'OIqm909GYYo',
#  'xN2PRAd8IZQ',
#  'AK7_m-aThfw',
#  'CYszyA2Xzdg',
#  'wT9ICgxRPYY',
#  'XruOBp7yPXU',
#  'SwSbnmqk3zY',
#  '8p_OzqIJ_p4',
#  '0Hhqf8L-b_0',
#  'M2NzvnfS-hI',
# ...

# %%
len(video_ids)
# Out:
# 89

# %% [markdown]
# # good one

# %%
data = dict(playlist_name = response['items'][0]['snippet']['title'],
             playlist_id = response['items'][0]['contentDetails']['description'])

# %%
get_playlist_id_from_channel(channel_id)
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'cBNIoH-31to7DysMzzc-BkA2djo',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'b48rQKLhwkijAorQFdMs2fGPdNE',
#    'id': 'UUiv4AccPaqsv_Jdr2dmu92A',
#    'snippet': {'publishedAt': '2021-05-30T13:24:35Z',
#     'channelId': 'UCiv4AccPaqsv_Jdr2dmu92A',
#     'title': 'Uploads from MY CYCLING SPOT',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9QDhesMz6eY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9QDhesMz6eY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9QDhesMz6eY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/9QDhesMz6eY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
def get_playlist_id_from_channel(channel_id):
    request = youtube.playlists().list(
        part='snippet,contentDetails',
        id=channel_id,
        maxResults=100
    )
    response = request.execute()
    
    return response

# %%
def get_playlist_id_from_channel(channel_id):
    playlist_ID = []
    request = youtube.playlists().list(
        part="snippet,contentDetails",
        id=channel_id,
        maxResults=50
    )
    response = request.execute()
    for item in response['items']:
        playlist_ID.append(item['contentDetails']['video_ids'])
        next_page_token = response.get('nextPageToken')
        while next_page_token is not None:
            request = youtube.playlists().list(
                      part="snippet,contentDetails",
                      id=channel_id,
                      maxResults=50,
                      pageToken = next_page_token)
            response = request.execute()

            for item in response['items']:
                playlist_ID.append(item['contentDetails']['video_ids'])
                next_page_token = response.get('nextPageToken')
        
    return playlist_ID

# %%
df=pd.DataFrame(video_df)
df
# Out:
#        video_id channelTitle  \
# 0   0QcEqFrhb_Y      techTFQ
# 1   smztq8sRAhk      techTFQ
# 2   7skZzocEU6c      techTFQ
# 3   LZGaRcDxj8I      techTFQ
# 4   rBPQ5fg_kiY      techTFQ
# ..          ...          ...
# 84  1aybOgni7lI      techTFQ
# 85  j09EQ-xlh88      techTFQ
# 86  7nzTDrio7vY      techTFQ
# 87  J-uCLHTIWZ4      techTFQ
# 88  _BMPh5M4BIY      techTFQ
#
#                                                 title  \
# 0   Learn SQL from me | Live SQL Training | SQL Bo...
# 1   Learn Python here | Learn Python Programming here
# 2   Solving a Complex SQL Interview problem | Prac...
# 3   REAL SQL Interview Problem | Hierarchical data...
# 4     Complete guide to Database Normalization in SQL
# ..                                                ...
# 84  How to install PostgreSQL on Mac OS | Install ...
# 85  Learn What is Database | Types of Database | DBMS
# 86                           Do you need a Smartwatch
# 87         MacBook Pro 13 2020  One Week Later Review
# ...

# %% [markdown]
# # starting again

# %%
def get_video_details(youtube, video_ids):
    """
    Get video statistics of all videos with given IDs
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with statistics of videos, i.e.:
        'channelTitle', 'title', 'description', 'tags', 'publishedAt'
        'viewCount', 'likeCount', 'favoriteCount', 'commentCount'
        'duration', 'definition', 'caption'
    """
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return(all_video_info)

# %%
video_df=get_video_details(youtube, video_ids)
video_df
# Out:
# [{'video_id': '0QcEqFrhb_Y',
#   'channelTitle': 'techTFQ',
#   'title': 'Learn SQL from me | Live SQL Training | SQL Bootcamp',
# ...

# %%
def get_comments_in_videos(youtube, video_ids):
    """
    Get top level comments as text from all videos with given IDs (only the first 10 comments due to quote limit of Youtube API)
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with video IDs and associated top level comment in text.
    
    """
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return(all_comments)

# %%
comment_df=get_comments_in_videos(youtube, video_ids)
comment_df
# Out:
# [{'video_id': '0QcEqFrhb_Y',
#   'comments': ['Great work... The way ur teaching is great.  ur videos helps me to get job🎉\nThanks. \nAwesome.. Go ahead. \nCan u do video -Why sql /plsql?\nFuture scope?',
#    'Brother, I have a query like this: I have used "show Databases" in MYSQL and "select name from sys.databases" in SQL SERVER to retrieve the names of all databases. I successfully obtained the database names. Now, my question is, can I store this result set of database names in another existing table?',
#    "I appreciate your videos and example queries. My main issue learning sql is that i don't understand how it applies to the on the job work.  Are data analysts being asked to write order, salary, and department queries? Meaning, what queries are employees writing on the job, rather than the practice ones you do?  Thanks.",
# ...

# %% [markdown]
# # alteration of video details

# %%
import pandas as pd
import numpy as np
from dateutil import parser
import isodate

# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
#sns.set(style="darkgrid", color_codes=True)

# Google API
#from googleapiclient.discovery import build

# %%
video_details['publishedAt'] =  video_details['publishedAt'].apply(lambda x: parser.parse(x)) 
video_details['pushblishDayName'] = video_details['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
pip install isodate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#video_details=pd.DataFrame(video_df)
video_details
# Out:
#        video_id     channelTitle  \
# 0   9QDhesMz6eY  MY CYCLING SPOT
# 1   wgWKZOQVuP8  MY CYCLING SPOT
# 2   NSrHj7w879Y  MY CYCLING SPOT
# 3   b-eSb-sG_6g  MY CYCLING SPOT
# 4   pcBuTNEjhXo  MY CYCLING SPOT
# 5   LWl58ol2eAI  MY CYCLING SPOT
# 6   rkGreFSBcJc  MY CYCLING SPOT
# 7   7TcycHW53TA  MY CYCLING SPOT
# 8   C7HlhmYnMvk  MY CYCLING SPOT
# 9   v4tYtbI19oM  MY CYCLING SPOT
# 10  bQFpNS1Yy5Q  MY CYCLING SPOT
# 11  EvUbefDUMzM  MY CYCLING SPOT
# 12  f-T1P32Yn7k  MY CYCLING SPOT
# 13  XyWAb9pBorw  MY CYCLING SPOT
# 14  38l9gcdV-Y4  MY CYCLING SPOT
# 15  9AzxI9IAwgQ  MY CYCLING SPOT
# 16  5l5b1pwqKck  MY CYCLING SPOT
# 17  7VrliyIrS7A  MY CYCLING SPOT
# 18  2byX730yM4s  MY CYCLING SPOT
# 19  JEAyKUgJ-K0  MY CYCLING SPOT
# 20  Cg5s_sZSPLE  MY CYCLING SPOT
# 21  l6ZwpiOrOOE  MY CYCLING SPOT
# 22  br1B-uggM44  MY CYCLING SPOT
# 23  3ekh7gYuLrM  MY CYCLING SPOT
# 24  E_zcLdrtjpU  MY CYCLING SPOT
# 25  lI5ztKBLpGc  MY CYCLING SPOT
# 26  l0ZLXp9JaRk  MY CYCLING SPOT
# ...

# %%
video_details.dtypes
# Out:
# video_id                             object
# channelTitle                         object
# title                                object
# description                          object
# tags                                 object
# publishedAt         datetime64[ns, tzutc()]
# viewCount                            object
# likeCount                            object
# favouriteCount                       object
# commentCount                         object
# duration                             object
# definition                           object
# caption                              object
# durationSecs                        float64
# pushblishDayName                     object
# dtype: object

# %%
video_details["publishedAt"].astype(str)
# Out:
# 0     2023-02-06 04:17:59+00:00
# 1     2022-10-30 13:17:05+00:00
# 2     2022-10-05 04:14:47+00:00
# 3     2022-09-01 15:34:21+00:00
# 4     2022-08-29 11:03:12+00:00
# 5     2022-08-26 17:27:05+00:00
# 6     2022-08-03 05:57:28+00:00
# 7     2022-07-27 04:53:34+00:00
# 8     2022-07-26 06:00:18+00:00
# 9     2022-07-20 10:45:28+00:00
# 10    2022-07-08 10:21:43+00:00
# 11    2022-07-05 12:23:34+00:00
# 12    2022-06-30 04:09:09+00:00
# 13    2022-06-13 05:46:17+00:00
# 14    2022-06-10 06:27:12+00:00
# 15    2022-05-30 17:50:32+00:00
# 16    2022-05-28 15:43:17+00:00
# 17    2022-05-14 07:17:51+00:00
# 18    2022-05-07 04:47:52+00:00
# 19    2022-04-22 07:15:12+00:00
# 20    2022-04-12 15:58:08+00:00
# 21    2022-04-05 05:38:08+00:00
# 22    2022-02-04 17:12:54+00:00
# 23    2022-01-26 17:38:34+00:00
# 24    2022-01-04 17:08:35+00:00
# 25    2022-01-03 03:13:09+00:00
# 26    2021-12-31 16:00:35+00:00
# 27    2021-12-18 09:22:45+00:00
# 28    2021-12-16 07:23:45+00:00
# ...

# %%
video_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 video_df
#
# NameError: name 'video_df' is not defined

# %%
# convert duration to seconds
import isodate
video_details['durationSecs'] = video_details['duration'].apply(lambda x: isodate.parse_duration(x))
video_details['durationSecs'] = video_details['durationSecs'].astype('timedelta64[s]')

# %%
final=video_details.to_dict()

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
final
# Out:
# {'video_id': {0: '9QDhesMz6eY',
#   1: 'wgWKZOQVuP8',
#   2: 'NSrHj7w879Y',
#   3: 'b-eSb-sG_6g',
#   4: 'pcBuTNEjhXo',
#   5: 'LWl58ol2eAI',
#   6: 'rkGreFSBcJc',
#   7: '7TcycHW53TA',
#   8: 'C7HlhmYnMvk',
#   9: 'v4tYtbI19oM',
#   10: 'bQFpNS1Yy5Q',
#   11: 'EvUbefDUMzM',
#   12: 'f-T1P32Yn7k',
#   13: 'XyWAb9pBorw',
#   14: '38l9gcdV-Y4',
#   15: '9AzxI9IAwgQ',
#   16: '5l5b1pwqKck',
#   17: '7VrliyIrS7A',
#   18: '2byX730yM4s',
#   19: 'JEAyKUgJ-K0',
#   20: 'Cg5s_sZSPLE',
#   21: 'l6ZwpiOrOOE',
#   22: 'br1B-uggM44',
#   23: '3ekh7gYuLrM',
#   24: 'E_zcLdrtjpU',
#   25: 'lI5ztKBLpGc',
#   26: 'l0ZLXp9JaRk',
#   27: 'Aw4p_Xj6oiw',
#   28: '_lR4wE7kOP8',
#   29: 'rOOTUl1AvME',
#   30: 'wa9Qutlri8Y',
#   31: 'vXKgnHl_R64',
#   32: 'HrDCrrXw3Kc',
#   33: 'O3YBgikRmq8',
#   34: '5KGiEeta83g',
#   35: 'f6-7OFo61gU',
#   36: 'nhSaXFZfFoc',
#   37: 'aSi3lC5bHds',
#   38: '4UAJ82ySk8I',
#   39: 'G4cz_n9f50A',
#   40: '7-uOmafYYsE',
#   41: 'SjEv1GMWNEs',
#   42: 'n8RukW0ZHrg',
# ...

# %% [markdown]
# # alteration ending

# %% [markdown]
# # final data pushing

# %%
def main(channel_id):
    channel_details = get_channel_stats(youtube,channel_id)
    video_ids= get_video_ids(youtube,playlist_id)
    video_df=get_video_details(youtube, video_ids)
    comment_df=get_comments_in_videos(youtube, video_ids)
    data = {'channel_details' : channel_details,
            'video_ids' : video_ids,
            'video_details' : video_df,
            'comment_details' : comment_df
               }
    return data

# %%
type(data)
# Out:
# dict

# %%
#channel_details = get_channel_stats(youtube,channel_id)
#video_ids= get_video_ids(youtube,playlist_id)
#video_df=get_video_details(youtube, video_ids[0])
#comment_df=get_comments_in_videos(youtube, video_ids[0])
data = {'channel_details' : channel_details,
            'video_ids' : video_ids,
            'video_details' : video_df,
            'comment_details' : comment_df
               }
print(data)
# Out:
# {'channel_details': {'Channel_name': 'techTFQ', 'Subscribers': '218000', 'Views': '10913123', 'Total_videos': '89'}, 'video_ids': ['0QcEqFrhb_Y', 'smztq8sRAhk', '7skZzocEU6c', 'LZGaRcDxj8I', 'rBPQ5fg_kiY', 'hvwltYazuQo', 'a-hFbr-4VQQ', 'pMNcPLc9Z7c', 'zZKb8FQRShs', 'jS5_hjFgfzA', '6UAU79FNBjQ', 'ZwFfiadQB3k', 'Det4ZjBSe3M', 'xUsY2jWQa1w', 'ueOUSjdAZY8', '90iK6gGvG_g', 'hsaPfEvForM', 'jb8XlF2dkoY', 'WhkNQ3g0U64', '_suB8xV9aPc', 'dWHSt0BVlv0', 'xJVWL7eMir0', 'h48xzQR3wNQ', 'S5gX-LLAZIM', 'LNlzx-YX8rI', 'WzkBZ0byoYE', 'weCZ1WynbMI', '3dOxGYkpVbE', '9dLXZrw6nac', 'i3xK7Nc414Q', 'H7YMumanHBA', '4p-G7fGhqRk', 'yLR1w4tZ36I', '-DiOp9vAEuM', 'O1o9m9T1c3k', '7hZYh9qXxe4', 'aE623ff7zkM', 'eXJGjbDo5KY', 'O52sweYbCyI', 'cLSxasHg9WY', 'l6XhSFAyvO0', 'nJIEIzF7tDw', 'RehbnzKHS28', '0OQJDd3QqQM', 'V6KPbGLYL4A', 'OIqm909GYYo', 'xN2PRAd8IZQ', 'AK7_m-aThfw', 'CYszyA2Xzdg', 'wT9ICgxRPYY', 'XruOBp7yPXU', 'SwSbnmqk3zY', '8p_OzqIJ_p4', '0Hhqf8L-b_0', 'M2NzvnfS-hI', 'QNfnuK-1YYY', 'PuBadaR8qC4', 'FNYdBLwZ6cE
# ...

# %%
def find_none_values(data):
    null_keys = []
    for key, value in dict.items():
        if value is None:
            null_keys.append(key)
    return null_keys

# Example dictionary
data = {'channel_details' : channel_details,
            'video_ids' : video_ids,
            'video_details' : video_df,
            'comment_details' : comment_df
               }

null_keys = find_none_values(data)
print("Keys with None values:", null_keys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[212], line 15
#       8 # Example dictionary
#       9 data = {'channel_details' : channel_details,
#      10             'video_ids' : video_ids,
#      11             'video_details' : video_df,
#      12             'comment_details' : comment_df
#      13                }
# ---> 15 null_keys = find_none_values(data)
#      16 print("Keys with None values:", null_keys)
#
# Cell In[212], line 3, in find_none_values(data)
#       1 def find_none_values(data):
#       2     null_keys = []
# ----> 3     for key, value in dict.items():
#       4         if value is None:
#       5             null_keys.append(key)
#
# TypeError: unbound method dict.items() needs an argument

# %%
output= main(youtube,channel_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 output= main(youtube,channel_id)
#
# TypeError: main() takes 1 positional argument but 2 were given

# %% [markdown]
# # mongodb connection

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
mydb =client["newone"]

# %%
information = mydb.data

# %%
information.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 information.insert_many(data)
#
# File ~\anaconda3\lib\site-packages\pymongo\_csot.py:106, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     104         with _TimeoutContext(timeout):
#     105             return func(self, *args, **kwargs)
# --> 106 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:709, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     660 """Insert an iterable of documents.
#     661
#     662   >>> db.test.count_documents({})
#    (...)
#     702 .. versionadded:: 3.0
#     703 """
#     704 if (
#     705     not isinstance(documents, abc.Iterable)
#     706     or isinstance(documents, abc.Mapping)
#     707     or not documents
#     708 ):
# ...
